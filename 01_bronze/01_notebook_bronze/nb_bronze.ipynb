# %%
country_df = spark.read.table("subscription.azure_blob_storage.country_master")
display(country_df)

# %%
country_df=country_df.drop("_file","_line","_modified","_fivetran_synced")
display(country_df)

# %%
customer_df = spark.table("subscription.azure_blob_storage.customer")
customer_df=customer_df.drop("_file","_line","_modified","_fivetran_synced")
display(customer_df)

# %%
epmloyee_df = spark.table("subscription.azure_blob_storage.employee")
epmloyee_df=epmloyee_df.drop("_file","_line","_modified","_fivetran_synced")
display(epmloyee_df)

# %%
fxrate_df = spark.table("subscription.azure_blob_storage.fx_rate")
fxrate_df=fxrate_df.drop("_file","_line","_modified","_fivetran_synced")
display(fxrate_df)

# %%
opportunity_df = spark.table("subscription.azure_blob_storage.opportunity")
opportunity_df=opportunity_df.drop("_file","_line","_modified","_fivetran_synced")
display(opportunity_df)

# %%
product_df = spark.table("subscription.azure_blob_storage.product")
product_df=product_df.drop("_file","_line","_modified","_fivetran_synced")
display(product_df)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_country"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
country_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_customers"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
customer_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_employee"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
epmloyee_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_fxrate"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
fxrate_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_opportunity"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
opportunity_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_products"
table_path = f"{catalog_name}.{schema_name}.{table_name}"
 
product_df.write.mode("overwrite").saveAsTable(table_path)

# %%
spark.sql("DROP TABLE IF EXISTS subscription_raw.subscription_schema.sb_country")

# %%
catalog_name = "subscription"
schema_name = "sub_schema"
table_name = "br_country"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

country_df.show()
 
country_df.write.mode("overwrite").saveAsTable(table_path)
